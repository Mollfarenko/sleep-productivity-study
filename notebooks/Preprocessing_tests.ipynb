# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/processed/sleep_productivity_clean.csv")

# %%
df.head()
# Out:
#    Age  Sleep Start Time  Sleep End Time  Total Sleep Hours  Sleep Quality  \
# 0   32             23.33            4.61               5.28              3
# 1   41             21.02            2.43               5.41              5
# 2   20             22.10            3.45               5.35              7
# 3   37             23.10            6.65               7.55              8
# 4   46             21.42            4.17               6.75             10
#
#    Exercise (mins/day)  Caffeine Intake (mg)  Screen Time Before Bed (mins)  \
# 0                   86                    87                            116
# 1                   32                    21                             88
# 2                   17                    88                             59
# 3                   46                    34                             80
# 4                   61                   269                             94
#
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Sleep Start Time', 'Sleep End Time', 'Total Sleep Hours',
#        'Sleep Quality', 'Exercise (mins/day)', 'Caffeine Intake (mg)',
#        'Screen Time Before Bed (mins)', 'Work Hours (hrs/day)',
#        'Productivity Score', 'Mood Score', 'Stress Level', 'Year', 'Month',
#        'Day', 'Gender_Male', 'Gender_Other'],
#       dtype='object')

# %%
df2 = pd.read_csv("../data/processed/sleep_productivity_classification.csv")

# %%
df2.head()
# Out:
#    Age  Sleep Start Time  Sleep End Time  Total Sleep Hours  Sleep Quality  \
# 0   32             23.33            4.61               5.28              3
# 1   41             21.02            2.43               5.41              5
# 2   20             22.10            3.45               5.35              7
# 3   37             23.10            6.65               7.55              8
# 4   46             21.42            4.17               6.75             10
#
#    Exercise (mins/day)  Caffeine Intake (mg)  Screen Time Before Bed (mins)  \
# 0                   86                    87                            116
# 1                   32                    21                             88
# 2                   17                    88                             59
# 3                   46                    34                             80
# 4                   61                   269                             94
#
# ...
